# %% [markdown]
# ## Step 1 : Project Overview and Import Modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
np.random.seed(0)
plt.style.use('ggplot')

import tensorflow as tf
print('Tensorflow version:', tf.__version__)
print('GPU detected:', tf.config.list_physical_devices('GPU'))
# Out:
# Tensorflow version: 2.1.0
# GPU detected: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ## Step 2 : Load and Explore the NER Dataset

# %% [markdown]
# *Essential info about tagged entities*:
# - geo = Geographical Entity
# - org = Organization
# - per = Person
# - gpe = Geopolitical Entity
# - tim = Time indicator
# - art = Artifact
# - eve = Event
# - nat = Natural Phenomenon

# %%
data = pd.read_csv('ner_dataset.csv', encoding='latin1')
data = data.fillna(method='ffill')
data.head(20)
# Out:
#      Sentence #           Word  POS    Tag
# 0   Sentence: 1      Thousands  NNS      O
# 1   Sentence: 1             of   IN      O
# 2   Sentence: 1  demonstrators  NNS      O
# 3   Sentence: 1           have  VBP      O
# 4   Sentence: 1        marched  VBN      O
# 5   Sentence: 1        through   IN      O
# 6   Sentence: 1         London  NNP  B-geo
# 7   Sentence: 1             to   TO      O
# 8   Sentence: 1        protest   VB      O
# 9   Sentence: 1            the   DT      O
# 10  Sentence: 1            war   NN      O
# 11  Sentence: 1             in   IN      O
# 12  Sentence: 1           Iraq  NNP  B-geo
# 13  Sentence: 1            and   CC      O
# 14  Sentence: 1         demand   VB      O
# 15  Sentence: 1            the   DT      O
# 16  Sentence: 1     withdrawal   NN      O
# 17  Sentence: 1             of   IN      O
# 18  Sentence: 1        British   JJ  B-gpe
# 19  Sentence: 1         troops  NNS      O

# %%
print('Unique words in corpus:', data['Word'].nunique())
print('Unique tags in corpus:', data['Tag'].nunique())
# Out:
# Unique words in corpus: 35178
# Unique tags in corpus: 17

# %%
words = list(set(data['Word'].values))
words.append('ENDPAD')
num_words = len(words)

# %%
tags = list(set(data['Tag'].values))
num_tags = len(tags)

# %% [markdown]
# ## Step 3 : Retrieve Sentences and Corresponding Tags

# %%
class SentenceGetter(object):
    def __init__(self, data):
        self.n_sent = 1
        self.data = data
        agg_func = lambda s: [(w,p,t) for w,p,t in zip(s['Word'].values.tolist(), s['POS'].values.tolist(), s['Tag'].values.tolist())]
        
        self.grouped = self.data.groupby('Sentence #').apply(agg_func)
        self.sentences = [s for s in self.grouped]

# %%
getter = SentenceGetter(data)
sentences = getter.sentences

# %%
sentences[0]
# Out:
# [('Thousands', 'NNS', 'O'),
#  ('of', 'IN', 'O'),
#  ('demonstrators', 'NNS', 'O'),
#  ('have', 'VBP', 'O'),
#  ('marched', 'VBN', 'O'),
#  ('through', 'IN', 'O'),
#  ('London', 'NNP', 'B-geo'),
#  ('to', 'TO', 'O'),
#  ('protest', 'VB', 'O'),
#  ('the', 'DT', 'O'),
#  ('war', 'NN', 'O'),
#  ('in', 'IN', 'O'),
#  ('Iraq', 'NNP', 'B-geo'),
#  ('and', 'CC', 'O'),
#  ('demand', 'VB', 'O'),
#  ('the', 'DT', 'O'),
#  ('withdrawal', 'NN', 'O'),
#  ('of', 'IN', 'O'),
#  ('British', 'JJ', 'B-gpe'),
#  ('troops', 'NNS', 'O'),
#  ('from', 'IN', 'O'),
#  ('that', 'DT', 'O'),
#  ('country', 'NN', 'O'),
#  ('.', '.', 'O')]

# %% [markdown]
# ## Step 4 : Define Mappings between Sentences and Tags

# %%
word2idx = {w:i+1 for i,w in enumerate(words)}
tag2idx = {t:i for i,t in enumerate(tags)}

# %%
word2idx
# Out:
# {'Amerindian': 1,
#  'Karua': 2,
#  'migrate': 3,
#  'Rato': 4,
#  'Land': 5,
#  'Ashr': 6,
#  'skillfully': 7,
#  'yet': 8,
#  'notified': 9,
#  'cold': 10,
#  'Landmarks': 11,
#  'Seeking': 12,
#  'hate': 13,
#  'manual': 14,
#  'Demirbag': 15,
#  'Virginie': 16,
#  'gores': 17,
#  'therefore': 18,
#  'PetroChina': 19,
#  'creek': 20,
#  'observed': 21,
#  'Partisans': 22,
#  'Cerda': 23,
#  'Le': 24,
#  'atmosphere': 25,
#  'SEE': 26,
#  'Managing': 27,
#  'Roe': 28,
#  'al-Hassani': 29,
#  'Monday': 30,
#  'legalize': 31,
#  'rebate': 32,
#  'block-to-block': 33,
#  'grossing': 34,
#  'disparate': 35,
#  'Minia': 36,
#  'mandate': 37,
#  'carve': 38,
#  'shrinking': 39,
#  'shoulders': 40,
#  'mentions': 41,
#  "MUTHARIKA'S": 42,
#  'brawny': 43,
#  'C.O': 44,
#  'most-watched': 45,
#  'Aristolbulo': 46,
#  'Freeman': 47,
#  'Acute': 48,
#  'eventually': 49,
#  'India': 50,
#  'repelled': 51,
#  'Endowment': 52,
#  'hitting': 53,
#  'safehouse': 54,
#  'transmissions': 55,
#  'Lien': 56,
#  "Sa'eed": 57,
#  '197-page': 58,
#  '710': 59,
#  'orders': 60,
#  'requital': 61,
#  'bronze': 62,
#  'anti-Ethiopian': 63,
#  'afterwards': 64,
#  'Joao': 65,
#  'bar': 66,
#  'Moldavia': 67,
#  'Alexi': 68,
#  'skiing': 69,
#  'forsook': 70,
#  'Mandy': 71,
#  'rules': 72,
#  'assignments': 73,
#  'Ashura': 74,
#  'Prosperous': 75,
#  'Ozawa': 76,
#  'cabinet': 77,
#  '3.6': 78,
#  'Country': 79,
#  'Ghangzhou': 80,
#  'Boat': 81,
#  'vitality': 82,
#  'Fadlallah': 83,
#  'Pashtoonkhwa': 84,
#  'spare': 85,
#  'nosedive': 86,
#  'Fund': 87,
#  'Unites': 88,
#  'Palestinian-claimed': 89,
#  'compiling': 90,
#  'forcing': 91,
#  'card': 92,
#  'contest': 93,
#  'Softball': 94,
#  'boyhood': 95,
#  'tuna': 96,
#  'Chidambaram': 97,
#  '820': 98,
#  'electronics': 99,
#  'Broadcaster': 100,
#  'preparedness': 101,
#  'abandoned': 102,
#  'flushed': 103,
#  'Siripala': 104,
#  'Tabare': 105,
#  'proliferating': 106,
#  'Mellon': 107,
#  'negotiation': 108,
#  'stakes': 109,
#  'integrate': 110,
#  'ASB': 111,
#  'Libyan-owned': 112,
#  'Besir': 113,
#  'health-care': 114,
#  'B-1': 115,
#  'Oprea': 116,
#  '5,52,300': 117,
#  'HART': 118,
#  'Flutur': 119,
#  'alternative-medicine': 120,
#  'reporter': 121,
#  'Bijbehera': 122,
#  '60-year': 123,
#  'addresses': 124,
#  'Khatami': 125,
#  'budget-price': 126,
#  'Gaz': 127,
#  'targeted': 128,
#  'inductees': 129,
#  'continental': 130,
#  'Canaveral': 131,
#  'Marie-Jeanne': 132,
#  'Napoleonic': 133,
#  'encourages': 134,
#  'derives': 135,
#  'Twenty-one-year-old': 136,
#  'lustily': 137,
#  'Model': 138,
#  'revisions': 139,
#  'Yurchikhin': 140,
#  'Freezing': 141,
#  'Landale': 142,
#  'Neurology': 143,
#  'bowl': 144,
#  'Prize-winning': 145,
#  'Finland': 146,
#  'Zine': 147,
#  'Computer': 148,
#  'Disney': 149,
#  'Culture': 150,
#  'predict': 151,
#  'goodbyes': 152,
#  'Dorfmeister': 153,
#  'Benshoofin': 154,
#  'claim': 155,
#  'Corporal': 156,
#  'Moinuddin': 157,
#  'yellow-shirts': 158,
#  'solitude': 159,
#  'Agitation': 160,
#  'swimmers': 161,
#  'firewood': 162,
#  'crocodile': 163,
#  'Hashemi': 164,
#  'Hakkari': 165,
#  'tenge': 166,
#  'Kiffa': 167,
#  'Coho': 168,
#  'petition': 169,
#  'Turin-born': 170,
#  'borrows': 171,
#  'automatically': 172,
#  'format': 173,
#  'camps': 174,
#  'disabilities': 175,
#  'unvarnished': 176,
#  'Timberlake': 177,
#  'Pat': 178,
#  'Townsend': 179,
#  'Snyder': 180,
#  'US-run': 181,
#  'Universal': 182,
#  'exaggerate': 183,
#  'Croatians': 184,
#  'preach': 185,
#  'sudden': 186,
#  'petrol': 187,
#  'insensible': 188,
#  'textiles': 189,
#  'worshipped': 190,
#  'grossly': 191,
#  'Karidza': 192,
#  'improvements': 193,
#  'strikeouts': 194,
#  'outset': 195,
#  'Tartous': 196,
#  'developed': 197,
#  'Serena': 198,
#  'disarming': 199,
#  'Yiru': 200,
#  'cartel': 201,
#  'bruised': 202,
#  'Participation': 203,
#  '79-year-old': 204,
#  'Uhm': 205,
#  'Welle': 206,
#  'Islamist-controlled': 207,
#  'mockery': 208,
#  'intuitive': 209,
#  'rapid-reaction': 210,
#  'complaints': 211,
#  'Writing': 212,
#  'Jabbar': 213,
#  'Dextre': 214,
#  'buster': 215,
#  'drops': 216,
#  'everybody': 217,
#  '1,28,000': 218,
#  'schools': 219,
#  'predicts': 220,
#  'Pago': 221,
#  'divides': 222,
#  'imports': 223,
#  'after-hours': 224,
#  'entitled': 225,
#  'annulment': 226,
#  'disclosed': 227,
#  'Big': 228,
#  'ghettos': 229,
#  'emigre': 230,
#  'Sayyaf': 231,
#  '2001': 232,
#  'renounces': 233,
#  'CIA-military': 234,
#  'relax': 235,
#  'Badghis': 236,
#  'drafted': 237,
#  'Aksel': 238,
#  'Saffir-Simpson': 239,
#  'explorer': 240,
#  'liters': 241,
#  'Cite': 242,
#  '2050': 243,
#  'shantytown': 244,
#  '65,000': 245,
#  '482': 246,
#  'warring': 247,
#  'services': 248,
#  'reigning': 249,
#  'consisting': 250,
#  'federation': 251,
#  'conquest': 252,
#  'Polls': 253,
#  'neck': 254,
#  'marketplace': 255,
#  'tropics': 256,
#  'Emomali': 257,
#  'Marcos': 258,
#  'near-total': 259,
#  'Abd-al-Nisr': 260,
#  'method': 261,
#  'cerebral': 262,
#  'Specialist': 263,
#  'Scott': 264,
#  'GDP': 265,
#  'deputy-leader': 266,
#  'uproot': 267,
#  'mental': 268,
#  'Kabungulu': 269,
#  'amidst': 270,
#  'strangely': 271,
#  '67,000': 272,
#  'Munoz': 273,
#  'compared': 274,
#  'Ask': 275,
#  'story': 276,
#  'searchers': 277,
#  'townspeople': 278,
#  'booked': 279,
#  'unjustifiable': 280,
#  'milder': 281,
#  'normalizing': 282,
#  'arranged': 283,
#  'efforts': 284,
#  'Joe': 285,
#  'organizations': 286,
#  'Guangxi': 287,
#  'Brong': 288,
#  'curtail': 289,
#  'second-in-command': 290,
#  'upheavals': 291,
#  'pirate': 292,
#  'great-uncle': 293,
#  'midair': 294,
#  '4.2': 295,
#  'historian': 296,
#  'Past': 297,
#  'Saqlawiyah': 298,
#  'Kabardino-Balkaria': 299,
#  'ex-Beatle': 300,
#  'Indo-Fijian': 301,
#  'de': 302,
#  'Mazlum-Der': 303,
#  'Catholics': 304,
#  'Conte': 305,
#  '454-member': 306,
#  'Lome': 307,
#  'A9': 308,
#  'Bankers': 309,
#  'Teresa': 310,
#  'sovereign': 311,
#  'Najam': 312,
#  'chartered': 313,
#  'rigors': 314,
#  '32': 315,
#  'collision': 316,
#  'anonymous': 317,
#  'composite': 318,
#  'Machinists': 319,
#  'Eastbourne': 320,
#  'respecting': 321,
#  '8.20': 322,
#  'Meek': 323,
#  'heat-trapping': 324,
#  'string': 325,
#  '250': 326,
#  'growling': 327,
#  'intact': 328,
#  'Caqueta': 329,
#  'Kurdish-majority': 330,
#  'suppressed': 331,
#  'firefighters': 332,
#  '93.3': 333,
#  'Nazareth': 334,
#  'Navarre': 335,
#  'valuables': 336,
#  'Ronit': 337,
#  'Fabiano': 338,
#  'Kam': 339,
#  'constituency': 340,
#  'Tata': 341,
#  'gateways': 342,
#  'Decree': 343,
#  'cudgelling': 344,
#  'Peking': 345,
#  'Indo-Aryan': 346,
#  'Erratic': 347,
#  'nation-wide': 348,
#  'gusts': 349,
#  'Nordic': 350,
#  'Telephone': 351,
#  '04-Jun': 352,
#  'foolish': 353,
#  'marshals': 354,
#  'Lausanne-based': 355,
#  'comparatively': 356,
#  'rogue': 357,
#  'seconds': 358,
#  'Zurabishvili': 359,
#  'Al-Arian': 360,
#  'Citroën': 361,
#  'routinely': 362,
#  'disability': 363,
#  'starred': 364,
#  'swaths': 365,
#  'Pradel': 366,
#  'Pass': 367,
#  'Genoese': 368,
#  'Kjetil': 369,
#  'ferry': 370,
#  'Gangs': 371,
#  'Luton': 372,
#  'Bager': 373,
#  'Allen': 374,
#  'Youssef': 375,
#  'Hanoun': 376,
#  'computing': 377,
#  'resolute': 378,
#  'bullet-riddled': 379,
#  'promulgated': 380,
#  'Bian': 381,
#  'Ad-Diyar': 382,
#  'Sheriff': 383,
#  'six-thousand': 384,
#  'explosives': 385,
#  '0.051655093': 386,
#  'Nahal': 387,
#  'McGrady': 388,
#  'Baathist': 389,
#  'KYI': 390,
#  'aviation': 391,
#  'sectarianism': 392,
#  '241-2661': 393,
#  '40-member': 394,
#  'Illegal': 395,
#  'stable': 396,
#  'identity': 397,
#  'haze-hit': 398,
#  'firmly': 399,
#  'prepares': 400,
#  'Crimean': 401,
#  'Nonetheless': 402,
#  'remanded': 403,
#  'barricades': 404,
#  '8,500': 405,
#  'jar': 406,
#  'service-oriented': 407,
#  'Pasadena': 408,
#  'commonplace': 409,
#  'code-named': 410,
#  'Mswati': 411,
#  'reinforced': 412,
#  'On': 413,
#  'disputed': 414,
#  'Miller': 415,
#  'three-set': 416,
#  'now': 417,
#  'SAVE': 418,
#  'infected': 419,
#  'robbing': 420,
#  'shipment': 421,
#  'consumers': 422,
#  'Twenty': 423,
#  'CORREA': 424,
#  'Akhmed': 425,
#  'Guni': 426,
#  'stars': 427,
#  'phosphate': 428,
#  'giant': 429,
#  'Rodham': 430,
#  'Jean': 431,
#  'detonator': 432,
#  'Olympian': 433,
#  'Al-Bahlul': 434,
#  'upwards': 435,
#  'mustard': 436,
#  'convictions': 437,
#  'locating': 438,
#  '220': 439,
#  'wire': 440,
#  'Perina': 441,
#  'renaming': 442,
#  'predecessor': 443,
#  'unused': 444,
#  'remoteness': 445,
#  'swing': 446,
#  'neurosurgeon': 447,
#  'Xianliang': 448,
#  'desecrating': 449,
#  'Cups': 450,
#  'Huot': 451,
#  'agencies': 452,
#  'jersey': 453,
#  '50-year-old': 454,
#  'democracies': 455,
#  'Akihito': 456,
#  'Entertainment': 457,
#  'Bittok': 458,
#  'al-Adha': 459,
#  'astronomers': 460,
#  'Secretary-General': 461,
#  'Babri': 462,
#  'harmonious': 463,
#  'Xsara': 464,
#  'Ana': 465,
#  'website': 466,
#  'incitement': 467,
#  'atheists': 468,
#  'Severe': 469,
#  'hospital': 470,
#  'Chiyangwa': 471,
#  'gain': 472,
#  'Toshiyuki': 473,
#  'Viewers': 474,
#  'military-police': 475,
#  'voided': 476,
#  'moans': 477,
#  'eight-tenths': 478,
#  'seeded': 479,
#  'prompt': 480,
#  'centrally-planned': 481,
#  'parity': 482,
#  'masterminds': 483,
#  'burned-out': 484,
#  'treatment': 485,
#  'Jalani': 486,
#  'Verhofstadt': 487,
#  'aides': 488,
#  'one-fourth': 489,
#  'fingerprint': 490,
#  'DreamWorks': 491,
#  'sensitive': 492,
#  'broadened': 493,
#  'applying': 494,
#  'urgency': 495,
#  'Specific': 496,
#  'troubles': 497,
#  'H7N3': 498,
#  'non-local': 499,
#  'Depot': 500,
#  '39-year-old': 501,
#  'blacklist': 502,
#  'IMF-recommended': 503,
#  'workable': 504,
#  'Santa': 505,
#  'misdirected': 506,
#  'smell': 507,
#  'plucked': 508,
#  'Watch': 509,
#  'grave': 510,
#  'Herb': 511,
#  'limped': 512,
#  'Earnings': 513,
#  'accommodations': 514,
#  'Matthew': 515,
#  'Yushchenko': 516,
#  '57th': 517,
#  'beneficiaries': 518,
#  'Bolivian': 519,
#  'high-risk': 520,
#  'Qaida-linked': 521,
#  'auctions': 522,
#  'stand-by': 523,
#  'extinguished': 524,
#  'immobility': 525,
#  'cocoa-growing': 526,
#  'TOURE': 527,
#  'Centers': 528,
#  'preachers': 529,
#  'naked': 530,
#  'Batlle': 531,
#  'frail': 532,
#  '104': 533,
#  'half-century': 534,
#  'bow': 535,
#  'grower': 536,
#  'Student': 537,
#  'landing': 538,
#  'Widhoelzl': 539,
#  'charm': 540,
#  'uncle': 541,
#  'immigration': 542,
#  'Hilda': 543,
#  'amended': 544,
#  'Comandante': 545,
#  'hopeless': 546,
#  'America': 547,
#  'begged': 548,
#  'connecting': 549,
#  'artemisinin': 550,
#  '2.7': 551,
#  'pitcher': 552,
#  'outsold': 553,
#  'stampede': 554,
#  'bass': 555,
#  'funding': 556,
#  'Africans': 557,
#  'Juste': 558,
#  'Baath': 559,
#  'histories': 560,
#  'French-Colombian': 561,
#  'diving': 562,
#  'Soviet-era': 563,
#  'Disneyland': 564,
#  'Dehui': 565,
#  'Age': 566,
#  'year-on-year': 567,
#  'nominating': 568,
#  'WAEMU': 569,
#  'host': 570,
#  'considerably': 571,
#  '12-hour': 572,
#  'match': 573,
#  'Socialist': 574,
#  'Ler': 575,
#  '07-Aug': 576,
#  'aiding': 577,
#  'Halvorsen': 578,
#  'promptly': 579,
#  'Legal': 580,
#  'photos': 581,
#  'campaign': 582,
#  'seven-car': 583,
#  'Paranavithana': 584,
#  '1,55,000': 585,
#  'construction': 586,
#  'Neiva': 587,
#  'taxes': 588,
#  'Beitar': 589,
#  'information': 590,
#  'al-Chalabi': 591,
#  'Chavez': 592,
#  'Baltasar': 593,
#  'Kasyanov': 594,
#  'Nations-hosted': 595,
#  'Chemet': 596,
#  'Toluca': 597,
#  'tenets': 598,
#  'blamed': 599,
#  'gullible': 600,
#  'Creator': 601,
#  'soften': 602,
#  'U.S.-hosted': 603,
#  'choir': 604,
#  '472': 605,
#  'Grammy-winning': 606,
#  'Eighty-eight': 607,
#  'vacationing': 608,
#  'equine': 609,
#  'Warming': 610,
#  'rush': 611,
#  'availability': 612,
#  'approach': 613,
#  'Volver': 614,
#  'worry': 615,
#  'Kievenaar': 616,
#  'destroying': 617,
#  'Reconstruction': 618,
#  'optician': 619,
#  'Balloon': 620,
#  'counterattack': 621,
#  'Masahiko': 622,
#  'McDaniel': 623,
#  '100-day': 624,
#  'caption': 625,
#  'wine': 626,
#  'sustaining': 627,
#  'poaching': 628,
#  'anti-Denmark': 629,
#  'BPA': 630,
#  'censor': 631,
#  'DIA': 632,
#  'Florida': 633,
#  'culls': 634,
#  'Amharic-language': 635,
#  'wet': 636,
#  'repairing': 637,
#  'military': 638,
#  'credence': 639,
#  'Chocolate': 640,
#  '1,100': 641,
#  'Gallop': 642,
#  'cutbacks': 643,
#  'rehabilitate': 644,
#  'wool': 645,
#  'severance': 646,
#  'Successive': 647,
#  'guests': 648,
#  'Pervasive': 649,
#  'nonpermanent': 650,
#  'schooled': 651,
#  'Arthurs': 652,
#  'religious': 653,
#  '150-meter-long': 654,
#  'Amen': 655,
#  'easing': 656,
#  'Success': 657,
#  'domination': 658,
#  '1814': 659,
#  'crossed': 660,
#  'Yaalon': 661,
#  'Mets': 662,
#  'gasses': 663,
#  'flood-stricken': 664,
#  'Ben': 665,
#  'air-dropping': 666,
#  'CD': 667,
#  'hairs': 668,
#  'Royals': 669,
#  'stockholders': 670,
#  'Arabian': 671,
#  'co-exist': 672,
#  '8.8-magnitude': 673,
#  'maximize': 674,
#  're-opening': 675,
#  'medical': 676,
#  'Embedded': 677,
#  '8956-kilometer': 678,
#  'legalization': 679,
#  'Alishar': 680,
#  'U.S-led': 681,
#  'item': 682,
#  'fiscally': 683,
#  '35-member': 684,
#  'Makhaya': 685,
#  'fields': 686,
#  'absolve': 687,
#  'operatives': 688,
#  'smaller': 689,
#  'Crime': 690,
#  'misunderstanding': 691,
#  'guns': 692,
#  'Narvaez': 693,
#  'Georgia': 694,
#  'semi-permanent': 695,
#  'bureau': 696,
#  'daytime': 697,
#  'waging': 698,
#  'hormone': 699,
#  'Gobernador': 700,
#  'Berruti': 701,
#  'search': 702,
#  'Foca': 703,
#  'disgust': 704,
#  'saving': 705,
#  'homemade': 706,
#  'Vakhitov': 707,
#  'Sovereign': 708,
#  'Ears': 709,
#  'Alessandria': 710,
#  'whose': 711,
#  '2-0': 712,
#  'finished': 713,
#  'Mekorot': 714,
#  'fights': 715,
#  'Department': 716,
#  '53.88': 717,
#  'deal': 718,
#  'swirled': 719,
#  'ludicrous': 720,
#  'formalities': 721,
#  'gas-based': 722,
#  'mullah': 723,
#  'kwaito': 724,
#  'Sriharokota': 725,
#  'sore': 726,
#  'Larkin': 727,
#  'commemorated': 728,
#  'sketch': 729,
#  '268': 730,
#  'peacekeeper': 731,
#  'mistakenly': 732,
#  'Peer': 733,
#  'Chanthalangsy': 734,
#  'isolate': 735,
#  'Prithvi': 736,
#  'inbalance': 737,
#  'less': 738,
#  'Kwan': 739,
#  'Sinn': 740,
#  'Montevideo': 741,
#  'Michaela': 742,
#  'Ri': 743,
#  'Weaver': 744,
#  'dome': 745,
#  'Viktor': 746,
#  'await': 747,
#  'rituals': 748,
#  'supposing': 749,
#  'pointless': 750,
#  'Wana': 751,
#  'biathlon': 752,
#  'band': 753,
#  'painting': 754,
#  'fearing': 755,
#  'arch-rivals': 756,
#  'Comedian': 757,
#  'contemporary': 758,
#  'decrease': 759,
#  'mosquito-borne': 760,
#  'Zabayda': 761,
#  'wrong': 762,
#  'Abune': 763,
#  'Mauritian': 764,
#  'Russia-Austria': 765,
#  '415': 766,
#  'Arizona': 767,
#  'dissolve': 768,
#  'defended': 769,
#  'cake': 770,
#  'Keesler': 771,
#  'supported': 772,
#  'Ndjabu': 773,
#  'shining': 774,
#  'four-decade-long': 775,
#  'Challenge': 776,
#  'ages': 777,
#  'custodian': 778,
#  'insight': 779,
#  'joined': 780,
#  '1946': 781,
#  'diminishing': 782,
#  '1747': 783,
#  'al-Naimi': 784,
#  'Aquarium': 785,
#  'military-installed': 786,
#  'Steele': 787,
#  'Somalia': 788,
#  'Final': 789,
#  'geographically': 790,
#  'continue': 791,
#  'Afghan-Pakistan': 792,
#  'Khalikov': 793,
#  'restive': 794,
#  'tetrahydrogestrinone': 795,
#  'Monkey': 796,
#  'Tibet': 797,
#  'Karabilah': 798,
#  'unconsciousness': 799,
#  'PRODUCTS': 800,
#  'Fasher': 801,
#  'outing': 802,
#  'Ohno': 803,
#  'relaxing': 804,
#  'ome': 805,
#  'lit': 806,
#  'Johan': 807,
#  'delegitimize': 808,
#  'Gasparovic': 809,
#  'long-suffering': 810,
#  'premiering': 811,
#  'key': 812,
#  'while': 813,
#  'allowing': 814,
#  'expected': 815,
#  'index': 816,
#  'Rajouri': 817,
#  'postcard': 818,
#  'Kazakhstani': 819,
#  'Anti-constitution': 820,
#  'creditor': 821,
#  'Bakri': 822,
#  'ingredient': 823,
#  'Moore': 824,
#  'fraud': 825,
#  'Reporters': 826,
#  'Tanzania-based': 827,
#  'Earthquake': 828,
#  'hearty': 829,
#  'Erkinbayev': 830,
#  'peeling': 831,
#  'Safin': 832,
#  'Smerdon': 833,
#  'commodies': 834,
#  'aiming': 835,
#  'Martinho': 836,
#  'pre-war': 837,
#  'non-profit': 838,
#  'provider': 839,
#  'Feith': 840,
#  'N': 841,
#  'Nabeel': 842,
#  'provide': 843,
#  'KANGAROO': 844,
#  'Internet': 845,
#  'Nabokov': 846,
#  'sulfur': 847,
#  'Preaching': 848,
#  'caller': 849,
#  'Gilgit': 850,
#  'Municipal': 851,
#  'Egyptians': 852,
#  'Gorbachev': 853,
#  'Seattle': 854,
#  'overstated': 855,
#  'Louis': 856,
#  'Hawo': 857,
#  'riddled': 858,
#  'produces': 859,
#  'infant': 860,
#  'Otunbayeva': 861,
#  'SARS': 862,
#  'wider': 863,
#  'Hobbs': 864,
#  'Ernesto': 865,
#  'thanked': 866,
#  'Barley': 867,
#  'focused': 868,
#  'elevator': 869,
#  'negotiator': 870,
#  'Adjarra': 871,
#  'Ortiz': 872,
#  'smile': 873,
#  'nomads': 874,
#  'Hubble': 875,
#  '4.8': 876,
#  'Rick': 877,
#  'Susan': 878,
#  'weaknesses': 879,
#  'Daltrey': 880,
#  '1916': 881,
#  'treaties': 882,
#  'avocados': 883,
#  'bisphenol': 884,
#  'Rawhi': 885,
#  'Ebrahim': 886,
#  'swear-in': 887,
#  'devoured': 888,
#  'Waruru': 889,
#  'equations': 890,
#  'Humala': 891,
#  'Gamboa': 892,
#  '1939': 893,
#  'Injured': 894,
#  'Valencia': 895,
#  'Daylam': 896,
#  'Jesse': 897,
#  'Ntawukulilyayo': 898,
#  'evaluates': 899,
#  'Schultz': 900,
#  'investigating': 901,
#  'scouts': 902,
#  'incensed': 903,
#  'segment': 904,
#  'Pius': 905,
#  'foodstuffs': 906,
#  'leniency': 907,
#  'Departments': 908,
#  'Copa': 909,
#  'arrivals': 910,
#  'statement': 911,
#  'breakers': 912,
#  'cartoonists': 913,
#  'Hushiar': 914,
#  'Qaratun': 915,
#  'their': 916,
#  'limited-over': 917,
#  'Qeshm': 918,
#  'Majlis': 919,
#  'Kaczynski': 920,
#  'reestablished': 921,
#  'Haziri': 922,
#  'Moreno-Ocampo': 923,
#  'Gavutu': 924,
#  'glades': 925,
#  'Henri': 926,
#  'peers': 927,
#  'Patu': 928,
#  'hobbled': 929,
#  'Scheffer': 930,
#  'extradite': 931,
#  'Akhmad': 932,
#  'Dawei-Ye': 933,
#  'grows': 934,
#  'meaningless': 935,
#  'Share': 936,
#  'horses': 937,
#  'mudslide-prone': 938,
#  'Jamrud': 939,
#  'yearly': 940,
#  'jumbo': 941,
#  'album-release': 942,
#  'Monty': 943,
#  'Consultative': 944,
#  'dribbled': 945,
#  'bylaw': 946,
#  'Reference': 947,
#  'Anatolianews': 948,
#  'notches': 949,
#  'severely': 950,
#  'Cantarell': 951,
#  'Devices': 952,
#  'Samantha': 953,
#  'body-searching': 954,
#  'Taliban': 955,
#  'one-and-a-half': 956,
#  'designated': 957,
#  'communal': 958,
#  'Bagosora': 959,
#  '02-Feb': 960,
#  'Kate': 961,
#  'Kolesnikov': 962,
#  'Wednesdays': 963,
#  '450-member': 964,
#  'Czech': 965,
#  '245': 966,
#  'Talangama': 967,
#  'refineries': 968,
#  'sorting': 969,
#  'Islamists': 970,
#  'candles': 971,
#  'large-scale': 972,
#  'photographic': 973,
#  'Keraterm': 974,
#  'bay': 975,
#  'ambassador-designate': 976,
#  'Hsiao': 977,
#  '\x96': 978,
#  'betrayed': 979,
#  'heed': 980,
#  'Ratnayke': 981,
#  '540': 982,
#  'duress': 983,
#  'Suleimaniya': 984,
#  'pave': 985,
#  'Facebook': 986,
#  'RMI': 987,
#  'spearker': 988,
#  '7,600': 989,
#  'xenophobic': 990,
#  '2,900': 991,
#  'Plum': 992,
#  'Japanto': 993,
#  'Monsanto': 994,
#  '107.25': 995,
#  'invests': 996,
#  'modernization': 997,
#  'kickball': 998,
#  '10-week': 999,
#  'Jake': 1000,
#  ...}

# %%
tag2idx
# Out:
# {'B-art': 6,
#  'B-eve': 7,
#  'B-geo': 8,
#  'B-gpe': 13,
#  'B-nat': 1,
#  'B-org': 5,
#  'B-per': 0,
#  'B-tim': 2,
#  'I-art': 11,
#  'I-eve': 10,
#  'I-geo': 3,
#  'I-gpe': 15,
#  'I-nat': 4,
#  'I-org': 9,
#  'I-per': 12,
#  'I-tim': 16,
#  'O': 14}

# %% [markdown]
# ## Step 5 : Padding Input Sentences and Creating Train-Test Splits

# %%
plt.hist([len(s) for s in sentences], bins=50)
plt.show()

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical

max_len = 50

X = [[word2idx[w[0]] for w in s] for s in sentences]
X = pad_sequences(maxlen=max_len, sequences=X, padding='post', value=num_words-1)

y = [[tag2idx[w[2]] for w in s] for s in sentences]
y = pad_sequences(maxlen=max_len, sequences=y, padding='post', value=tag2idx['O'])
y = [to_categorical(i, num_classes=num_tags) for i in y]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=1)

# %%
y_train = np.array(y_train)
y_test = np.array(y_test)

# %% [markdown]
# ## Step 6 : Build and Compile a Bidirectional LSTM Model

# %%
from tensorflow.keras import Model, Input
from tensorflow.keras.layers import LSTM, Embedding, Dense
from tensorflow.keras.layers import TimeDistributed, SpatialDropout1D, Bidirectional

# %%
input_word = Input(shape=(max_len,))
model = Embedding(input_dim=num_words, output_dim=max_len, input_length=max_len)(input_word)
model = SpatialDropout1D(0.1)(model)
model = Bidirectional(LSTM(units=100, return_sequences=True, recurrent_dropout=0.1))(model)
out = TimeDistributed(Dense(num_tags, activation='softmax'))(model)
model = Model(input_word, out)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 50)]              0
# _________________________________________________________________
# embedding (Embedding)        (None, 50, 50)            1758950
# _________________________________________________________________
# spatial_dropout1d (SpatialDr (None, 50, 50)            0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 50, 200)           120800
# _________________________________________________________________
# time_distributed (TimeDistri (None, 50, 17)            3417
# =================================================================
# Total params: 1,883,167
# Trainable params: 1,883,167
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ## Step 7 : Train the Model

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from livelossplot.tf_keras import PlotLossesCallback

# %%
'''%%time

chkpt = ModelCheckpoint('model_weights.h5', monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=True, mode='min')
early_stopping = EarlyStopping(monitor='val_accuracy', patience=1, mode='max')
callbacks = [PlotLossesCallback(), chkpt, early_stopping]

history = model.fit(x_train, y_train, validation_split=0.2, batch_size=32, epochs=100, verbose=1, callbacks=callbacks)'''
# Out:
# Log-loss (cost function):
# training   (min:    0.032, max:    0.191, cur:    0.032)
# validation (min:    0.047, max:    0.068, cur:    0.047)
#
# accuracy:
# training   (min:    0.957, max:    0.990, cur:    0.990)
# validation (min:    0.980, max:    0.986, cur:    0.986)
#
# Epoch 00004: val_loss did not improve from 0.04707
# 34530/34530 [==============================] - 343s 10ms/sample - loss: 0.0322 - accuracy: 0.9900 - val_loss: 0.0471 - val_accuracy: 0.9857
# Wall time: 19min 48s

# %% [markdown]
# ## Step 8 : Evaluate Named Entity Recognition Model

# %%
model.load_weights('model_weights.h5')

# %%
model.evaluate(x_test, y_test)
# Out:
# 4796/4796 [==============================] - 13s 3ms/sample - loss: 0.0489 - accuracy: 0.9852
# [0.0489239660002372, 0.98517513]

# %%
i = np.random.randint(0, x_test.shape[0])
p = model.predict(x_test[i].reshape(1,-1))
p = np.argmax(p, axis=-1)

y_actual = np.argmax(y_test[i], axis=-1)
print('{:15}{}\t{}'.format('Word', 'Actual', 'Pred'))
print('-'*30)
for w, actual, pred in zip(x_test[i], y_actual, p[0]):
    print('{:15}{}\t{}'.format(words[w-1], tags[actual], tags[pred]))
# Out:
# Word           Actual	Pred
# ------------------------------
# Nepalese       B-gpe	B-gpe
# police         O	O
# detained       O	O
# 41             O	O
# Tibetans       B-gpe	B-gpe
# Sunday         B-tim	B-tim
# for            O	O
# illegal        O	O
# entry          O	O
# into           O	O
# the            O	O
# country        O	O
# .              O	O
# Baja           O	O
# Baja           O	O
# Baja           O	O
# Baja           O	O
# Baja           O	O
# Baja           O	O
# Baja           O	O
# Baja           O	O
# Baja           O	O
# Baja           O	O
# Baja           O	O
# Baja           O	O
# Baja           O	O
# Baja           O	O
# Baja           O	O
# Baja           O	O
# Baja           O	O
# Baja           O	O
# Baja           O	O
# Baja           O	O
# Baja           O	O
# Baja           O	O
# Baja           O	O
# Baja           O	O
# Baja           O	O
# Baja           O	O
# Baja           O	O
# Baja           O	O
# Baja           O	O
# Baja           O	O
# Baja           O	O
# Baja           O	O
# Baja           O	O
# Baja           O	O
# Baja           O	O
# Baja           O	O
# Baja           O	O
